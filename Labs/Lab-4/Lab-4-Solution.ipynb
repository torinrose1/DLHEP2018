# %% [markdown]
# # Lab 4- Model Building
#
# In this lab, we will attempt to follow the first paper on Deep Learning in High Energy physics [P. Baldi, et al](https://arxiv.org/pdf/1402.4735.pdf). This paper demonstrates that Deep Neural Networks can learn from rad data the features that are typically used by physicists for searches for exotics particles. The authors provide the data they used for this paper. They considered two benchmark scenarios. We will focus on the SUSY benchmark. The physics behind this sample will be discussed in class.
#
# The data is provided as a comma separated file:

# %%
filename="/data/afarbin/DLClass/SUSY/SUSY.csv"
# print out the first 5 lines using unix head command
# !head -5  "/data/afarbin/DLClass/SUSY/SUSY.csv"
# Out:
# 0.000000000000000000e+00,9.728614687919616699e-01,6.538545489311218262e-01,1.176224589347839355e+00,1.157156467437744141e+00,-1.739873170852661133e+00,-8.743090629577636719e-01,5.677649974822998047e-01,-1.750000417232513428e-01,8.100607395172119141e-01,-2.525521218776702881e-01,1.921887040138244629e+00,8.896374106407165527e-01,4.107718467712402344e-01,1.145620822906494141e+00,1.932632088661193848e+00,9.944640994071960449e-01,1.367815494537353516e+00,4.071449860930442810e-02
# 1.000000000000000000e+00,1.667973041534423828e+00,6.419061869382858276e-02,-1.225171446800231934e+00,5.061022043228149414e-01,-3.389389812946319580e-01,1.672542810440063477e+00,3.475464344024658203e+00,-1.219136357307434082e+00,1.295456290245056152e-02,3.775173664093017578e+00,1.045977115631103516e+00,5.680512785911560059e-01,4.819284379482269287e-01,0.000000000000000000e+00,4.484102725982666016e-01,2.053557634353637695e-01,1.321893453598022461e+00,3.775840103626251221e-01
# ...

# %% [markdown]
# Each row represents a LHC collision event. Each column contains some observable from that event. The variable names are:

# %%
VarNames=["signal", "l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi", "MET", "MET_phi", "MET_rel", "axial_MET", "M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos_theta_r1"]

# %% [markdown]
# Some of these variables represent the "raw" kinematics of the observed final state particles, while others are "features" that are derived from these raw quantities:

# %%
RawNames=["l_1_pT", "l_1_eta","l_1_phi", "l_2_pT", "l_2_eta", "l_2_phi"]
FeatureNames=[ "MET", "MET_phi", "MET_rel", "axial_MET", "M_R", "M_TR_2", "R", "MT2", "S_R", "M_Delta_R", "dPhi_r_b", "cos_theta_r1"]

# %% [markdown]
# We will use pandas to read in the file, and matplotlib to make plots. The following ensures pandas is installed and sets everything up:

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now we can read the data into a pandas dataframe:

# %%
df = pd.read_csv(filename, dtype='float64', names=VarNames)

# %% [markdown]
# You can see the data in Jupyter by just evaluating the dataframe:

# %%
df
# Out:
#          signal    l_1_pT   l_1_eta   l_1_phi    l_2_pT   l_2_eta   l_2_phi  \
# 0           0.0  0.972861  0.653855  1.176225  1.157156 -1.739873 -0.874309
# 1           1.0  1.667973  0.064191 -1.225171  0.506102 -0.338939  1.672543
# 2           1.0  0.444840 -0.134298 -0.709972  0.451719 -1.613871 -0.768661
# 3           1.0  0.381256 -0.976145  0.693152  0.448959  0.891753 -0.677328
# 4           1.0  1.309996 -0.690089 -0.676259  1.589283 -0.693326  0.622907
# 5           0.0  0.456398  1.099371  1.512453  0.751772  0.638967 -0.742216
# 6           0.0  0.437818 -1.119883 -1.336823  0.502320 -1.717515  1.017067
# 7           0.0  0.571656  0.205696  0.425950  0.578514  0.927399 -1.101478
# 8           1.0  2.112812  0.742983 -0.330539  0.805253 -0.028887 -1.446679
# 9           0.0  1.001869 -0.471788  0.555614  1.233368  1.255548 -1.052491
# 10          0.0  0.840115  0.958249 -0.585658  1.317930 -1.063730  1.246235
# ...

# %% [markdown]
# The first column stores the "truth" label of whether an event was signal or background. Pandas makes it easy to create dataframes that store only the signal or background events:

# %%
df_sig=df[df.signal==1]
df_bkg=df[df.signal==0]

# %% [markdown]
# The following example plots the signal and background distributions of every variable. Note that we use VarNames[1:] to skip the first variable, which was the true label.

# %%
for var in VarNames[1:]:
    print var
    plt.figure()
    plt.hist(df_sig[var],bins=100,histtype="step", color="red",label="background",stacked=True)
    plt.hist(df_bkg[var],bins=100,histtype="step", color="blue", label="signal",stacked=True)
    plt.legend(loc='upper right')
    plt.show()
# Out:
# l_1_pT
# l_1_eta
# l_1_phi
# l_2_pT
# l_2_eta
# l_2_phi
# MET
# MET_phi
# MET_rel
# axial_MET
# M_R
# M_TR_2
# R
# MT2
# S_R
# M_Delta_R
# dPhi_r_b
# cos_theta_r1

# %% [markdown]
# ## Building a classifier with Scikit-Learn
#
# [Scikit-learn](http://scikit-learn.org) is a rich python library for data science, including machine learning. For example, we can build a Fisher Discriminant (aka Linear Discriminant Analysis, or LDA). The [LDA Documentation](http://scikit-learn.org/stable/modules/lda_qda.html#dimensionality-reduction-using-linear-discriminant-analysis) does as great job explaining this classifier. Here's how we instanciate the classifier:

# %%
import sklearn.discriminant_analysis as DA
Fisher=DA.LinearDiscriminantAnalysis()

# %% [markdown]
# Lets separate the data into inputs (X) vs outputs (Y) and training vs testing samples:

# %%
N_Train=4000000

Train_Sample=df[:N_Train]
Test_Sample=df[N_Train:]

X_Train=Train_Sample[VarNames[1:]]
y_Train=Train_Sample["signal"]

X_Test=Test_Sample[VarNames[1:]]
y_Test=Test_Sample["signal"]

Test_sig=Test_Sample[Test_Sample.signal==1]
Test_bkg=Test_Sample[Test_Sample.signal==0]

# %% [markdown]
# We can train the classifier as follow:

# %%
Fisher.fit(X_Train,y_Train)
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#               solver='svd', store_covariance=False, tol=0.0001)

# %% [markdown]
# We can plot the output, comparing signal and background:

# %%
plt.figure()
plt.hist(Fisher.decision_function(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="blue", label="signal",stacked=True)
plt.hist(Fisher.decision_function(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="red", label="background",stacked=True)
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# And we can make a ROC curve and evaluate the AUC:

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, _ = roc_curve(y_Test, Fisher.decision_function(X_Test))

roc_auc = auc(fpr, tpr)

plt.plot(fpr,tpr,color='darkorange',label='ROC curve (area = %0.2f)' % roc_auc)
plt.legend(loc="lower right")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.show()

# %% [markdown]
# ## Exercise 4.1
#
# Train the Fisher performance of using the raw, features, and raw+features as input. Compare the performance one a single plot. Add cells to this notebook as needed.

# %%
fig=plt.figure(figsize=(16,4))

Plots=fig.add_subplot(121)
ROCPlots=fig.add_subplot(122)

X_Train_Raw=Train_Sample[VarNames[1:6]]
y_Train_Raw=Train_Sample['signal']
X_Test_Raw=Test_Sample[VarNames[1:6]]
y_Test_Raw=Test_Sample["signal"]
Fisher.fit(X_Train_Raw,y_Train_Raw)
Plots.hist(Fisher.decision_function(Test_sig[VarNames[1:6]]),bins=100,histtype="step", color="blue", label="Raw sig",stacked=True)
Plots.hist(Fisher.decision_function(Test_bkg[VarNames[1:6]]),bins=100,histtype="step", color="red", label="Raw bkgd",stacked=True)
Rfpr, Rtpr, _ = roc_curve(y_Test_Raw, Fisher.decision_function(X_Test_Raw))
Rroc_auc = auc(Rfpr, Rtpr)
ROCPlots.plot(Rfpr,Rtpr,color='darkorange',label='Raw ROC curve (area = %0.2f)' % Rroc_auc)

X_Train_Features=Train_Sample[VarNames[7:]]
y_Train_Features=Train_Sample['signal']
X_Test_Features=Test_Sample[VarNames[7:]]
y_Test_Features=Test_Sample["signal"]
Fisher.fit(X_Train_Features,y_Train_Features)
Plots.hist(Fisher.decision_function(Test_sig[VarNames[7:]]),bins=100,histtype="step", color="green", label="Features sig",stacked=True)
Plots.hist(Fisher.decision_function(Test_bkg[VarNames[7:]]),bins=100,histtype="step", color="black", label="Features bkgd",stacked=True)
Ffpr, Ftpr, _ = roc_curve(y_Test_Features, Fisher.decision_function(X_Test_Features))
Froc_auc = auc(Ffpr, Ftpr)
ROCPlots.plot(Ffpr,Ftpr,color='darkblue',label='Features ROC curve (area = %0.2f)' % Froc_auc)

X_Train_All=Train_Sample[VarNames[1:]]
y_Train_All=Train_Sample['signal']
X_Test_All=Test_Sample[VarNames[1:]]
y_Test_All=Test_Sample["signal"]
Fisher.fit(X_Train_All,y_Train_All)
Plots.hist(Fisher.decision_function(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="yellow", label="All sig",stacked=True)
Plots.hist(Fisher.decision_function(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="orange", label="All bkgd",stacked=True)
Afpr, Atpr, _ = roc_curve(y_Test_All, Fisher.decision_function(X_Test_All))
Aroc_auc = auc(Afpr, Atpr)
ROCPlots.plot(Afpr,Atpr,color='darkgreen',label='All ROC curve (area = %0.2f)' % Aroc_auc)

Plots.legend(loc='upper right')
ROCPlots.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Exercise 4.2
#
# Select 3 different classifiers from the techniques listed [here](http://scikit-learn.org/stable/supervised_learning.html#supervised-learning). Note that you can use the multi-layer peceptron to build a deep network, though training may be prohibitively slow, so avoid this technique. Perform the comparison in exercise 1 for each classifier. Compare your conclusions for your selected techniques to the paper.

# %%
import sklearn.linear_model as LM
GradientDescent=LM.SGDClassifier()

fig=plt.figure(figsize=(16,4))

Plots=fig.add_subplot(121)
ROCPlots=fig.add_subplot(122)

X_Train_Raw=Train_Sample[VarNames[1:6]]
y_Train_Raw=Train_Sample['signal']
X_Test_Raw=Test_Sample[VarNames[1:6]]
y_Test_Raw=Test_Sample["signal"]
GradientDescent.fit(X_Train_Raw,y_Train_Raw)
Plots.hist(GradientDescent.decision_function(Test_sig[VarNames[1:6]]),bins=100,histtype="step", color="blue", label="Raw sig",stacked=True)
Plots.hist(GradientDescent.decision_function(Test_bkg[VarNames[1:6]]),bins=100,histtype="step", color="red", label="Raw bkgd",stacked=True)
Rfpr, Rtpr, _ = roc_curve(y_Test_Raw, GradientDescent.decision_function(X_Test_Raw))
Rroc_auc = auc(Rfpr, Rtpr)
ROCPlots.plot(Rfpr,Rtpr,color='darkorange',label='Raw ROC curve (area = %0.2f)' % Rroc_auc)

X_Train_Features=Train_Sample[VarNames[7:]]
y_Train_Features=Train_Sample['signal']
X_Test_Features=Test_Sample[VarNames[7:]]
y_Test_Features=Test_Sample["signal"]
GradientDescent.fit(X_Train_Features,y_Train_Features)
Plots.hist(GradientDescent.decision_function(Test_sig[VarNames[7:]]),bins=100,histtype="step", color="green", label="Features sig",stacked=True)
Plots.hist(GradientDescent.decision_function(Test_bkg[VarNames[7:]]),bins=100,histtype="step", color="black", label="Features bkgd",stacked=True)
Ffpr, Ftpr, _ = roc_curve(y_Test_Features, GradientDescent.decision_function(X_Test_Features))
Froc_auc = auc(Ffpr, Ftpr)
ROCPlots.plot(Ffpr,Ftpr,color='darkblue',label='Features ROC curve (area = %0.2f)' % Froc_auc)

X_Train_All=Train_Sample[VarNames[1:]]
y_Train_All=Train_Sample['signal']
X_Test_All=Test_Sample[VarNames[1:]]
y_Test_All=Test_Sample["signal"]
GradientDescent.fit(X_Train_All,y_Train_All)
Plots.hist(GradientDescent.decision_function(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="yellow", label="All sig",stacked=True)
Plots.hist(GradientDescent.decision_function(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="orange", label="All bkgd",stacked=True)
Afpr, Atpr, _ = roc_curve(y_Test_All, GradientDescent.decision_function(X_Test_All))
Aroc_auc = auc(Afpr, Atpr)
ROCPlots.plot(Afpr,Atpr,color='darkgreen',label='All ROC curve (area = %0.2f)' % Aroc_auc)

Plots.legend(loc='upper right')
ROCPlots.legend(loc='lower right')
plt.show()

# %%
import sklearn.linear_model as LM
LogisticRegression=LM.LogisticRegression()

fig=plt.figure(figsize=(16,4))

Plots=fig.add_subplot(121)
ROCPlots=fig.add_subplot(122)

X_Train_Raw=Train_Sample[VarNames[1:6]]
y_Train_Raw=Train_Sample['signal']
X_Test_Raw=Test_Sample[VarNames[1:6]]
y_Test_Raw=Test_Sample["signal"]
LogisticRegression.fit(X_Train_Raw,y_Train_Raw)
Plots.hist(LogisticRegression.decision_function(Test_sig[VarNames[1:6]]),bins=100,histtype="step", color="blue", label="Raw sig",stacked=True)
Plots.hist(LogisticRegression.decision_function(Test_bkg[VarNames[1:6]]),bins=100,histtype="step", color="red", label="Raw bkgd",stacked=True)
Rfpr, Rtpr, _ = roc_curve(y_Test_Raw, LogisticRegression.decision_function(X_Test_Raw))
Rroc_auc = auc(Rfpr, Rtpr)
ROCPlots.plot(Rfpr,Rtpr,color='darkorange',label='Raw ROC curve (area = %0.2f)' % Rroc_auc)

X_Train_Features=Train_Sample[VarNames[7:]]
y_Train_Features=Train_Sample['signal']
X_Test_Features=Test_Sample[VarNames[7:]]
y_Test_Features=Test_Sample["signal"]
LogisticRegression.fit(X_Train_Features,y_Train_Features)
Plots.hist(LogisticRegression.decision_function(Test_sig[VarNames[7:]]),bins=100,histtype="step", color="green", label="Features sig",stacked=True)
Plots.hist(LogisticRegression.decision_function(Test_bkg[VarNames[7:]]),bins=100,histtype="step", color="black", label="Features bkgd",stacked=True)
Ffpr, Ftpr, _ = roc_curve(y_Test_Features, LogisticRegression.decision_function(X_Test_Features))
Froc_auc = auc(Ffpr, Ftpr)
ROCPlots.plot(Ffpr,Ftpr,color='darkblue',label='Features ROC curve (area = %0.2f)' % Froc_auc)

X_Train_All=Train_Sample[VarNames[1:]]
y_Train_All=Train_Sample['signal']
X_Test_All=Test_Sample[VarNames[1:]]
y_Test_All=Test_Sample["signal"]
LogisticRegression.fit(X_Train_All,y_Train_All)
Plots.hist(LogisticRegression.decision_function(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="yellow", label="All sig",stacked=True)
Plots.hist(LogisticRegression.decision_function(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="orange", label="All bkgd",stacked=True)
Afpr, Atpr, _ = roc_curve(y_Test_All, LogisticRegression.decision_function(X_Test_All))
Aroc_auc = auc(Afpr, Atpr)
ROCPlots.plot(Afpr,Atpr,color='darkgreen',label='All ROC curve (area = %0.2f)' % Aroc_auc)

Plots.legend(loc='upper right')
ROCPlots.legend(loc='lower right')
plt.show()

# %%
import sklearn.naive_bayes as NB
NaiveBayes=NB.GaussianNB()

fig=plt.figure(figsize=(16,4))

Plots=fig.add_subplot(121)
ROCPlots=fig.add_subplot(122)

X_Train_Raw=Train_Sample[VarNames[1:6]]
y_Train_Raw=Train_Sample['signal']
X_Test_Raw=Test_Sample[VarNames[1:6]]
y_Test_Raw=Test_Sample["signal"]
NaiveBayes.fit(X_Train_Raw,y_Train_Raw)
Plots.hist(NaiveBayes.predict(Test_sig[VarNames[1:6]]),bins=100,histtype="step", color="blue", label="Raw sig",stacked=True)
Plots.hist(NaiveBayes.predict(Test_bkg[VarNames[1:6]]),bins=100,histtype="step", color="red", label="Raw bkgd",stacked=True)
Rfpr, Rtpr, _ = roc_curve(y_Test_Raw, NaiveBayes.predict(X_Test_Raw))
Rroc_auc = auc(Rfpr, Rtpr)
ROCPlots.plot(Rfpr,Rtpr,color='darkorange',label='Raw ROC curve (area = %0.2f)' % Rroc_auc)

X_Train_Features=Train_Sample[VarNames[7:]]
y_Train_Features=Train_Sample['signal']
X_Test_Features=Test_Sample[VarNames[7:]]
y_Test_Features=Test_Sample["signal"]
NaiveBayes.fit(X_Train_Features,y_Train_Features)
Plots.hist(NaiveBayes.predict(Test_sig[VarNames[7:]]),bins=100,histtype="step", color="green", label="Features sig",stacked=True)
Plots.hist(NaiveBayes.predict(Test_bkg[VarNames[7:]]),bins=100,histtype="step", color="black", label="Features bkgd",stacked=True)
Ffpr, Ftpr, _ = roc_curve(y_Test_Features, NaiveBayes.predict(X_Test_Features))
Froc_auc = auc(Ffpr, Ftpr)
ROCPlots.plot(Ffpr,Ftpr,color='darkblue',label='Features ROC curve (area = %0.2f)' % Froc_auc)

X_Train_All=Train_Sample[VarNames[1:]]
y_Train_All=Train_Sample['signal']
X_Test_All=Test_Sample[VarNames[1:]]
y_Test_All=Test_Sample["signal"]
NaiveBayes.fit(X_Train_All,y_Train_All)
Plots.hist(NaiveBayes.predict(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="yellow", label="All sig",stacked=True)
Plots.hist(NaiveBayes.predict(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="orange", label="All bkgd",stacked=True)
Afpr, Atpr, _ = roc_curve(y_Test_All, NaiveBayes.predict(X_Test_All))
Aroc_auc = auc(Afpr, Atpr)
ROCPlots.plot(Afpr,Atpr,color='darkgreen',label='All ROC curve (area = %0.2f)' % Aroc_auc)

Plots.legend(loc='upper right')
ROCPlots.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Exercise 4.3
#
# The following function calculates the significance of the observation of the signal given the number of expected Signal and Background events, using the simple formula $\sigma_S= \frac{N_S}{\sqrt{N_S+N_B}}$. Read through the code carefully.

# %%
import numpy as np

def PlotSignificance(N_S,N_B, N_S_min=1):
    plt.figure()
    eff_sig,bins_sig,p_sig=plt.hist(Fisher.decision_function(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="blue", label="signal",cumulative=-1,stacked=True,normed=True)
    eff_bkg,bins_bkg,p_bkg=plt.hist(Fisher.decision_function(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="red", label="background",cumulative=-1,stacked=True,normed=True)
    plt.legend(loc='upper right')
    plt.show()
    
    good_bins = np.where(eff_sig*N_S>=N_S_min)

    print len(good_bins[0])
    if len(good_bins[0])<1:
        print "Insufficient Signal."
        return 0,0,0
    
    significance=(N_S*eff_sig)/np.sqrt((N_B*eff_bkg)+(N_S*eff_sig))

    plt.figure()
    plt.plot(bins_sig[:-1],significance)
    
    max_sign=np.max(significance[good_bins])
    max_signI=np.argmax(significance[good_bins])
    
    TestNs=1
    TestNb=1e11
    TestSignificance=(TestNs*eff_sig)/np.sqrt((TestNb*eff_bkg)+(TestNs*eff_sig))
    count=100
    MaxTestSignificance=np.max(TestSignificance[good_bins])
    while MaxTestSignificance<5:
        count=count+100
        New_Ns=TestNs*count
        New_Nb=TestNb*count
        TestSignificance=(New_Ns*eff_sig)/np.sqrt((New_Nb*eff_bkg)+(New_Ns*eff_sig))
        MaxTestSignificance=np.max(TestSignificance[good_bins])
    
    plt.show()
    print "Max significance at ", bins_sig[max_signI], " of", max_sign
    return bins_sig[max_signI],max_sign, max_signI,New_Ns
    

Var=PlotSignificance(1000000,1e11)
Var
print "%d signal events are required for this classifier to make a discovery claim of 5 sigma" % Var[3]
# Out:
# 100
# Max significance at  -5.92031800082  of 3.1622618489
# 20000000 signal events are required for this classifier to make a discovery claim of 5 sigma

# %%
def PlotSignificance(N_S,N_B, N_S_min=1):
    plt.figure()
    eff_sig,bins_sig,p_sig=plt.hist(GradientDescent.decision_function(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="blue", label="signal",cumulative=-1,stacked=True,normed=True)
    eff_bkg,bins_bkg,p_bkg=plt.hist(GradientDescent.decision_function(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="red", label="background",cumulative=-1,stacked=True,normed=True)
    plt.legend(loc='upper right')
    plt.show()
    
    good_bins = np.where(eff_sig*N_S>=N_S_min)

    print len(good_bins[0])
    if len(good_bins[0])<1:
        print "Insufficient Signal."
        return 0,0,0
    
    significance=(N_S*eff_sig)/np.sqrt((N_B*eff_bkg)+(N_S*eff_sig))

    plt.figure()
    plt.plot(bins_sig[:-1],significance)
    
    max_sign=np.max(significance[good_bins])
    max_signI=np.argmax(significance[good_bins])
    
    TestNs=1
    TestNb=1e11
    TestSignificance=(TestNs*eff_sig)/np.sqrt((TestNb*eff_bkg)+(TestNs*eff_sig))
    count=100
    MaxTestSignificance=np.max(TestSignificance[good_bins])
    while MaxTestSignificance<5:
        count=count+100
        New_Ns=TestNs*count
        New_Nb=TestNb*count
        TestSignificance=(New_Ns*eff_sig)/np.sqrt((New_Nb*eff_bkg)+(New_Ns*eff_sig))
        MaxTestSignificance=np.max(TestSignificance[good_bins])
    
    plt.show()
    print "Max significance at ", bins_sig[max_signI], " of", max_sign
    return bins_sig[max_signI],max_sign, max_signI,New_Ns
    
Var1=PlotSignificance(1000000,1e11)
Var1

print "%d signal events are required for this classifier to make a discovery claim of 5 sigma" % Var1[3]
# Out:
# 100
# Max significance at  -8.10254647017  of 3.1622618489
# (-8.1025464701656738, 3.162261848898662, 0)

# %%
def PlotSignificance(N_S,N_B, N_S_min=1):
    plt.figure()
    eff_sig,bins_sig,p_sig=plt.hist(LogisticRegression.decision_function(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="blue", label="signal",cumulative=-1,stacked=True,normed=True)
    eff_bkg,bins_bkg,p_bkg=plt.hist(LogisticRegression.decision_function(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="red", label="background",cumulative=-1,stacked=True,normed=True)
    plt.legend(loc='upper right')
    plt.show()
    
    good_bins = np.where(eff_sig*N_S>=N_S_min)

    print len(good_bins[0])
    if len(good_bins[0])<1:
        print "Insufficient Signal."
        return 0,0,0
    
    significance=(N_S*eff_sig)/np.sqrt((N_B*eff_bkg)+(N_S*eff_sig))

    plt.figure()
    plt.plot(bins_sig[:-1],significance)
    
    max_sign=np.max(significance[good_bins])
    max_signI=np.argmax(significance[good_bins])
    
    TestNs=1
    TestNb=1e11
    TestSignificance=(TestNs*eff_sig)/np.sqrt((TestNb*eff_bkg)+(TestNs*eff_sig))
    count=100
    MaxTestSignificance=np.max(TestSignificance[good_bins])
    while MaxTestSignificance<5:
        count=count+100
        New_Ns=TestNs*count
        New_Nb=TestNb*count
        TestSignificance=(New_Ns*eff_sig)/np.sqrt((New_Nb*eff_bkg)+(New_Ns*eff_sig))
        MaxTestSignificance=np.max(TestSignificance[good_bins])
    
    plt.show()
    print "Max significance at ", bins_sig[max_signI], " of", max_sign
    return bins_sig[max_signI],max_sign, max_signI,New_Ns
    
Var2=PlotSignificance(1000000,1e11)
Var2

print "%d signal events are required for this classifier to make a discovery claim of 5 sigma" % Var2[3]
# Out:
# 100
# Max significance at  -10.4585384425  of 3.1622618489
# (-10.458538442538988, 3.1622618488986629, 0)

# %%
def PlotSignificance(N_S,N_B, N_S_min=1):
    plt.figure()
    eff_sig,bins_sig,p_sig=plt.hist(NaiveBayes.predict(Test_sig[VarNames[1:]]),bins=100,histtype="step", color="blue", label="signal",cumulative=-1,stacked=True,normed=True)
    eff_bkg,bins_bkg,p_bkg=plt.hist(NaiveBayes.predict(Test_bkg[VarNames[1:]]),bins=100,histtype="step", color="red", label="background",cumulative=-1,stacked=True,normed=True)
    plt.legend(loc='upper right')
    plt.show()
    
    good_bins = np.where(eff_sig*N_S>=N_S_min)

    print len(good_bins[0])
    if len(good_bins[0])<1:
        print "Insufficient Signal."
        return 0,0,0
    
    significance=(N_S*eff_sig)/np.sqrt((N_B*eff_bkg)+(N_S*eff_sig))

    plt.figure()
    plt.plot(bins_sig[:-1],significance)
    
    max_sign=np.max(significance[good_bins])
    max_signI=np.argmax(significance[good_bins])
    
    TestNs=1
    TestNb=1e11
    TestSignificance=(TestNs*eff_sig)/np.sqrt((TestNb*eff_bkg)+(TestNs*eff_sig))
    count=100
    MaxTestSignificance=np.max(TestSignificance[good_bins])
    while MaxTestSignificance<5:
        count=count+100
        New_Ns=TestNs*count
        New_Nb=TestNb*count
        TestSignificance=(New_Ns*eff_sig)/np.sqrt((New_Nb*eff_bkg)+(New_Ns*eff_sig))
        MaxTestSignificance=np.max(TestSignificance[good_bins])
    
    plt.show()
    print "Max significance at ", bins_sig[max_signI], " of", max_sign
    return bins_sig[max_signI],max_sign, max_signI,New_Ns
    
Var3=PlotSignificance(1000000,1e11)
Var3

print "%d signal events are required for this classifier to make a discovery claim of 5 sigma" % Var3[3]
# Out:
# 100
# Max significance at  0.01  of 5.24262934349
# (0.01, 5.2426293434859952, 1)

# %% [markdown]
# Answer the following questions:
#    * What are we computing when making a normalized cummulative plot?
#            Where the signal and background can effectively be separated/where to make a "cut".
#    * Assume that the experiment produces 1 signal event for every $10^{11}$ background events. For each of your classifiers, how many signal events need to be produced to be able to make a $5\sigma$ discovery claim?
#            x

# %% [markdown]
# ## Honors problems:
#
# ### Exercise 4.4
#
# Read the paper and attempt to reproduce the results, as closely as possible, using scikit-learn.
# Try using the [multi-layer peceptron](http://scikitlearn.org/stable/modules/neural_networks_supervised.html#multi-layer-perceptron) to build a deep network. Or if you are capable, try it using [Keras Scikit-learn interface](https://keras.io/scikit-learn-api/).
